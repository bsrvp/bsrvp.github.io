# %% [markdown]
# ### Pandas Basics

# %%
import pandas as pd

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df['one'])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
df['three'] = pd.Series([20,21,22],index=['a','b','c'])

# %%
print(df)
# Out:
#    one  two  three
# a  1.0    1   20.0
# b  2.0    2   21.0
# c  3.0    3   22.0
# d  NaN    4    NaN

# %%
df['four'] = df['two'] + df['three']

# %%
print(df)
# Out:
#    one  two  three  four
# a  1.0    1   20.0  21.0
# b  2.0    2   21.0  23.0
# c  3.0    3   22.0  25.0
# d  NaN    4    NaN   NaN

# %%
print(df[1:3])
# Out:
#    one  two  three  four
# b  2.0    2   21.0  23.0
# c  3.0    3   22.0  25.0

# %%
df.loc['a']
# Out:
# one       1.0
# two       1.0
# three    20.0
# four     21.0
# Name: a, dtype: float64

# %%
df[0:2]
# Out:
#    one  two  three  four
# a  1.0    1   20.0  21.0
# b  2.0    2   21.0  23.0

# %%
df1 = pd.DataFrame([[1,2],[3,4]],index=['a','b'])

# %%
df2 = pd.DataFrame([[5,6],[7,8]],index=['a','b'])

# %%
df3 = pd.DataFrame([[9,10],[11,12]],columns = [2,3])

# %%
print(df1)
print(df2)
print(df3)
# Out:
#    0  1
# a  1  2
# b  3  4
#    0  1
# a  5  6
# b  7  8
#     2   3
# 0   9  10
# 1  11  12

# %%
df1 = df1.append(df3)
# Out:
# C:\Users\BSRVPrasad\AppData\Local\Temp\ipykernel_11592\1176390029.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df3)

# %%
print(df1)
# Out:
#      0    1     2     3
# a  1.0  2.0   NaN   NaN
# b  3.0  4.0   NaN   NaN
# 0  NaN  NaN   9.0  10.0
# 1  NaN  NaN  11.0  12.0

# %%
df1.size
# Out:
# 16

# %%
df1.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
df2 =  pd.DataFrame([[14,15],[10,11]], columns=['one','two'])

# %%
df2.dtypes
# Out:
# one    int64
# two    int64
# dtype: object

# %%
df1.shape
# Out:
# (4, 4)

# %%
df1
# Out:
#      0    1     2     3
# a  1.0  2.0   NaN   NaN
# b  3.0  4.0   NaN   NaN
# 0  NaN  NaN   9.0  10.0
# 1  NaN  NaN  11.0  12.0

# %%
df1.cumsum()
# Out:
#      0    1     2     3
# a  1.0  2.0   NaN   NaN
# b  4.0  6.0   NaN   NaN
# 0  NaN  NaN   9.0  10.0
# 1  NaN  NaN  20.0  22.0

# %%
df = df.append(df2)
# Out:
# C:\Users\BSRVPrasad\AppData\Local\Temp\ipykernel_11592\948459739.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)

# %%
df
# Out:
#     one  two  three  four
# a   1.0    1   20.0  21.0
# b   2.0    2   21.0  23.0
# c   3.0    3   22.0  25.0
# d   NaN    4    NaN   NaN
# 0  14.0   15    NaN   NaN
# 1  10.0   11    NaN   NaN

# %%
df3 =  pd.DataFrame([[24,25],[20,21]], columns=['one','two'], index = ['a',0])

# %%
df3
# Out:
#    one  two
# a   24   25
# 0   20   21

# %%
df = df.append(df3)
# Out:
# C:\Users\BSRVPrasad\AppData\Local\Temp\ipykernel_11592\1066977462.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df3)

# %%
df
# Out:
#     one  two  three  four
# a   1.0    1   20.0  21.0
# b   2.0    2   21.0  23.0
# c   3.0    3   22.0  25.0
# d   NaN    4    NaN   NaN
# 0  14.0   15    NaN   NaN
# 1  10.0   11    NaN   NaN
# a  24.0   25    NaN   NaN
# 0  20.0   21    NaN   NaN

# %%
df.T
# Out:
#           a     b     c    d     0     1     a     0
# one     1.0   2.0   3.0  NaN  14.0  10.0  24.0  20.0
# two     1.0   2.0   3.0  4.0  15.0  11.0  25.0  21.0
# three  20.0  21.0  22.0  NaN   NaN   NaN   NaN   NaN
# four   21.0  23.0  25.0  NaN   NaN   NaN   NaN   NaN

# %%
df.info() #Checks whether there are any null values in each column of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, a to 0
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     7 non-null      float64
#  1   two     8 non-null      int64
#  2   three   3 non-null      float64
#  3   four    3 non-null      float64
# dtypes: float64(3), int64(1)
# memory usage: 620.0+ bytes

# %%
df.axes
# Out:
# [Index(['a', 'b', 'c', 'd', 0, 1, 'a', 0], dtype='object'),
#  Index(['one', 'two', 'three', 'four'], dtype='object')]

# %%
df.dtypes
# Out:
# one      float64
# two        int64
# three    float64
# four     float64
# dtype: object

# %%
df.empty
# Out:
# False

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (8, 4)

# %%
df.size
# Out:
# 32

# %%
df.describe()
# Out:
#              one        two  three  four
# count   7.000000   8.000000    3.0   3.0
# mean   10.571429  10.250000   21.0  23.0
# std     9.162553   9.269767    1.0   2.0
# min     1.000000   1.000000   20.0  21.0
# 25%     2.500000   2.750000   20.5  22.0
# 50%    10.000000   7.500000   21.0  23.0
# 75%    17.000000  16.500000   21.5  24.0
# max    24.000000  25.000000   22.0  25.0

# %%
df.sum()
# Out:
# one      74.0
# two      82.0
# three    63.0
# four     69.0
# dtype: float64

# %%
df.sum(axis=1) #df.sum(1)
# Out:
# a    43.0
# b    48.0
# c    53.0
# d     4.0
# 0    29.0
# 1    21.0
# a    49.0
# 0    41.0
# dtype: float64

# %%
df.mean()
# Out:
# one      10.571429
# two      10.250000
# three    21.000000
# four     23.000000
# dtype: float64

# %%
df.head()
# Out:
#     one  two  three  four
# a   1.0    1   20.0  21.0
# b   2.0    2   21.0  23.0
# c   3.0    3   22.0  25.0
# d   NaN    4    NaN   NaN
# 0  14.0   15    NaN   NaN

# %%
df.tail()
# Out:
#     one  two  three  four
# d   NaN    4    NaN   NaN
# 0  14.0   15    NaN   NaN
# 1  10.0   11    NaN   NaN
# a  24.0   25    NaN   NaN
# 0  20.0   21    NaN   NaN

# %%
df1
# Out:
#      0    1     2     3
# a  1.0  2.0   NaN   NaN
# b  3.0  4.0   NaN   NaN
# 0  NaN  NaN   9.0  10.0
# 1  NaN  NaN  11.0  12.0

# %%
df1.columns
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df1
# Out:
#      0    1     2     3
# a  1.0  2.0   NaN   NaN
# b  3.0  4.0   NaN   NaN
# 0  NaN  NaN   9.0  10.0
# 1  NaN  NaN  11.0  12.0

# %%
df1.drop(1,axis=1)
# Out:
#      0     2     3
# a  1.0   NaN   NaN
# b  3.0   NaN   NaN
# 0  NaN   9.0  10.0
# 1  NaN  11.0  12.0

# %%
df1
# Out:
#      0    1     2     3
# a  1.0  2.0   NaN   NaN
# b  3.0  4.0   NaN   NaN
# 0  NaN  NaN   9.0  10.0
# 1  NaN  NaN  11.0  12.0

# %%
df11 = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df21 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])

# %%
df11 = pd.concat([df11,df21],ignore_index=True)

# %%
df11
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
df11
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
df21
# Out:
#    a  b
# 0  5  6
# 1  7  8

# %%
del df11

# %%
df11 = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])

# %%
df11
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %%
df11 = df11.append(df21)
# Out:
# C:\Users\BSRVPrasad\AppData\Local\Temp\ipykernel_11592\899904042.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df11 = df11.append(df21)

# %%
df11.drop('b',axis=1)
# Out:
#    a
# 0  1
# 1  3
# 0  5
# 1  7

# %%
df11
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %% [markdown]
# ### Reading the data from Text files and Excel Files

# %%
data1 = pd.read_csv('data1.txt')

# %%
data1
# Out:
#    1   2   3   4
# 0  5   6   7   8
# 1  9  10  11  12

# %%
data2 = pd.read_csv('data2.txt')

# %%
data2
# Out:
#      1     2    3   4
# 0  5.0   NaN  7.0   8
# 1  NaN  10.0  NaN  12

# %%
WQdata = pd.read_excel('WQ.xlsx')

# %%
WQdata.shape
# Out:
# (36, 16)

# %%
WQdata.describe()
# Out:
#           St. No      Depth        S.D       W.T   Salinity  Turbidity  \
# count  36.000000  35.000000  34.000000  35.00000  35.000000  35.000000
# mean   18.500000   1.554286   0.533676  30.76000  16.045714  16.842286
# std    10.535654   0.786501   0.389326   1.49119   8.986210  12.950463
# min     1.000000   0.250000   0.010000  28.50000   0.000000   1.800000
# 25%     9.750000   0.800000   0.250000  29.70000  10.800000   7.070000
# 50%    18.500000   1.250000   0.500000  30.30000  14.200000  13.800000
# 75%    27.250000   2.250000   0.750000  31.85000  19.550000  25.820000
# max    36.000000   3.250000   1.500000  34.20000  35.300000  55.600000
#
#               DO         pH         TSM      NH4-N      NO2-N      NO3-N  \
# count  35.000000  35.000000   35.000000  35.000000  35.000000  35.000000
# mean    7.236571   8.390571   33.102829   3.422857   0.499429   3.169714
# std     1.341053   0.375264   32.129909   3.344098   0.446153   3.949222
# ...

# %%
WQdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   St. No     36 non-null     int64
#  1   Depth      35 non-null     float64
#  2   S.D        34 non-null     float64
#  3   W.T        35 non-null     float64
#  4   Salinity   35 non-null     float64
#  5   Turbidity  35 non-null     float64
#  6   DO         35 non-null     float64
#  7   pH         35 non-null     float64
#  8   TSM        35 non-null     float64
#  9   NH4-N      35 non-null     float64
#  10  NO2-N      35 non-null     float64
#  11  NO3-N      35 non-null     float64
#  12  PO4-P      35 non-null     float64
#  13  SiO2-Si    35 non-null     float64
#  14  TN         31 non-null     float64
#  15  TP         21 non-null     float64
# dtypes: float64(15), int64(1)
# memory usage: 4.6 KB

# %%
import pandas as pd
import numpy as np
xl = pd.ExcelFile('WQ.xlsx')

# %%
sheets = xl.sheet_names
print(sheets)
# Out:
# ['May 04', 'June 04', 'July 04', 'Aug 04', 'Sep 04', 'Oct 04', 'Nov 04', 'Dec 04', 'Jan 05', 'Feb 05', 'Mar 05', 'Apr 05', 'May 05', 'June 05', 'July 05', 'Aug 05', 'Sep 05', 'Oct 05', 'Nov 05', 'Dec 05', 'Jan 06', 'Feb 06', 'Mar 06', 'Apr 06', 'May 06', 'June 06', 'July 06', 'Aug 06', 'Sep 06']

# %%
WQ = pd.DataFrame()
for name in sheets:
    temp = pd.read_excel('WQ.xlsx',sheet_name=name)
    Month = pd.DataFrame([name]*temp.shape[0],columns=['Month'])
    temp = pd.concat([Month,temp],axis=1)
    #print(temp)
    if WQ.empty == True:
        WQ = temp
    else:
        WQ = pd.concat([WQ, temp])

# %%
WQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 35
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      1044 non-null   object
#  1   St. No     1044 non-null   int64
#  2   Depth      1034 non-null   float64
#  3   S.D        1033 non-null   float64
#  4   W.T        1035 non-null   float64
#  5   Salinity   1035 non-null   float64
#  6   Turbidity  1030 non-null   float64
#  7   DO         1035 non-null   float64
#  8   pH         1036 non-null   float64
#  9   TSM        1026 non-null   float64
#  10  NH4-N      1026 non-null   float64
#  11  NO2-N      1036 non-null   float64
#  12  NO3-N      1031 non-null   float64
#  13  PO4-P      1035 non-null   float64
#  14  SiO2-Si    1033 non-null   float64
#  15  TN         1027 non-null   float64
#  16  TP         1012 non-null   float64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
WQ.tail()
# Out:
#      Month  St. No  Depth  S.D   W.T  Salinity  Turbidity    DO    pH    TSM  \
# 31  Sep 06      32   1.50  0.0  29.5      0.16       45.4  6.97  7.27   53.0
# 32  Sep 06      33   2.50  0.0  29.0      0.13      150.0  6.82  7.61  212.0
# 33  Sep 06      34   1.75  0.0  31.5      0.20      332.0  6.20  8.01  243.0
# 34  Sep 06      35   1.50  0.0  31.0      1.54      170.0  6.35  8.07   98.0
# 35  Sep 06      36   3.50  0.5  31.5      1.66      252.0  6.28  8.12  323.0
#
#       NH4-N    NO2-N     NO3-N    PO4-P   SiO2-Si        TN       TP
# 31  0.41024  0.12741   0.29809  0.55437  103.2355   9.58318  1.33308
# 32  0.46152  0.42333  14.55427  0.73916  178.9055  92.91518  1.67164
# 33  0.46152  0.25800   7.82650  0.46741  170.2575  49.99920  1.05800
# 34  0.92304  0.19350   8.18885  0.57611  142.1515  44.99928  1.20612
# 35  1.74352  0.27950   7.16675  0.23914  143.2325  40.83268  0.59248

# %%
WQ.tail()
# Out:
#      Month  St. No  Depth  S.D   W.T  Salinity  Turbidity    DO    pH    TSM  \
# 31  Sep 06      32   1.50  0.0  29.5      0.16       45.4  6.97  7.27   53.0
# 32  Sep 06      33   2.50  0.0  29.0      0.13      150.0  6.82  7.61  212.0
# 33  Sep 06      34   1.75  0.0  31.5      0.20      332.0  6.20  8.01  243.0
# 34  Sep 06      35   1.50  0.0  31.0      1.54      170.0  6.35  8.07   98.0
# 35  Sep 06      36   3.50  0.5  31.5      1.66      252.0  6.28  8.12  323.0
#
#       NH4-N    NO2-N     NO3-N    PO4-P   SiO2-Si        TN       TP
# 31  0.41024  0.12741   0.29809  0.55437  103.2355   9.58318  1.33308
# 32  0.46152  0.42333  14.55427  0.73916  178.9055  92.91518  1.67164
# 33  0.46152  0.25800   7.82650  0.46741  170.2575  49.99920  1.05800
# 34  0.92304  0.19350   8.18885  0.57611  142.1515  44.99928  1.20612
# 35  1.74352  0.27950   7.16675  0.23914  143.2325  40.83268  0.59248

# %%
WQ.describe()
# Out:
#             St. No        Depth          S.D          W.T     Salinity  \
# count  1044.000000  1034.000000  1033.000000  1035.000000  1035.000000
# mean     18.500000     1.742621     0.576462    29.256531    12.163740
# std      10.393274     0.792122     0.532560     2.734294     9.174874
# min       1.000000     0.100000     0.000000    20.100000     0.000000
# 25%       9.750000     1.250000     0.150000    27.850000     4.405000
# 50%      18.500000     1.750000     0.500000    29.500000    11.130000
# 75%      27.250000     2.250000     1.000000    31.300000    19.100000
# max      36.000000     4.500000     3.750000    37.800000    35.300000
#
#          Turbidity           DO           pH          TSM        NH4-N  \
# count  1030.000000  1035.000000  1036.000000  1026.000000  1026.000000
# mean     54.999029     7.159511     8.304210    75.191285     2.960870
# std     113.721950     1.700331     0.417211   148.795049     2.705394
# ...

# %%
WQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 35
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      1044 non-null   object
#  1   St. No     1044 non-null   int64
#  2   Depth      1034 non-null   float64
#  3   S.D        1033 non-null   float64
#  4   W.T        1035 non-null   float64
#  5   Salinity   1035 non-null   float64
#  6   Turbidity  1030 non-null   float64
#  7   DO         1035 non-null   float64
#  8   pH         1036 non-null   float64
#  9   TSM        1026 non-null   float64
#  10  NH4-N      1026 non-null   float64
#  11  NO2-N      1036 non-null   float64
#  12  NO3-N      1031 non-null   float64
#  13  PO4-P      1035 non-null   float64
#  14  SiO2-Si    1033 non-null   float64
#  15  TN         1027 non-null   float64
#  16  TP         1012 non-null   float64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
WQG = WQ.groupby('Month').describe()

# %%
WQG
# Out:
#         St. No                                                Depth            \
#          count  mean        std  min   25%   50%    75%   max count      mean
# Month
# Apr 05    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  36.0  1.380556
# Apr 06    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  35.0  1.478571
# Aug 04    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  36.0  1.847222
# Aug 05    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  35.0  2.231429
# Aug 06    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  36.0  2.354167
# Dec 04    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  36.0  1.568889
# Dec 05    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  36.0  1.823611
# Feb 05    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  36.0  1.388889
# Feb 06    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  36.0  1.479167
# Jan 05    36.0  18.5  10.535654  1.0  9.75  18.5  27.25  36.0  36.0  1.548611
# ...

# %%
WQ.plot()
# Out:
# <Axes: >

# %%
WQ.plot(kind='bar',y='DO')
# Out:
# <Axes: >

# %%
WQ.plot(kind='scatter',x='W.T',y='DO')
# Out:
# <Axes: xlabel='W.T', ylabel='DO'>

# %%
WQ.plot(kind='area',subplots=True, figsize=(8,15), title='Area Plots')
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
WQ.plot(kind='box',y='DO')
# Out:
# <Axes: >

# %%
WQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 35
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      1044 non-null   object
#  1   St. No     1044 non-null   int64
#  2   Depth      1034 non-null   float64
#  3   S.D        1033 non-null   float64
#  4   W.T        1035 non-null   float64
#  5   Salinity   1035 non-null   float64
#  6   Turbidity  1030 non-null   float64
#  7   DO         1035 non-null   float64
#  8   pH         1036 non-null   float64
#  9   TSM        1026 non-null   float64
#  10  NH4-N      1026 non-null   float64
#  11  NO2-N      1036 non-null   float64
#  12  NO3-N      1031 non-null   float64
#  13  PO4-P      1035 non-null   float64
#  14  SiO2-Si    1033 non-null   float64
#  15  TN         1027 non-null   float64
#  16  TP         1012 non-null   float64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
data = np.random.randn(5,3)

# %%
df = pd.DataFrame(data,index=['a','c','d','f','h'],columns=['I','II','III'])

# %%
df
# Out:
#           I        II       III
# a -1.984875 -0.006250 -1.260459
# c -0.261671  1.707445  0.234977
# d -0.316402 -0.878059  0.159859
# f  0.052401  0.023698 -0.885729
# h  0.532185  0.322891  0.139575

# %%
df = df.reindex(['a','b','c','d','e','f','g','h','i'])

# %%
df
# Out:
#           I        II       III
# a -1.984875 -0.006250 -1.260459
# b       NaN       NaN       NaN
# c -0.261671  1.707445  0.234977
# d -0.316402 -0.878059  0.159859
# e       NaN       NaN       NaN
# f  0.052401  0.023698 -0.885729
# g       NaN       NaN       NaN
# h  0.532185  0.322891  0.139575

# %%
df.isnull()
# Out:
#        I     II    III
# a  False  False  False
# b   True   True   True
# c  False  False  False
# d  False  False  False
# e   True   True   True
# f  False  False  False
# g   True   True   True
# h  False  False  False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, a to h
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   I       5 non-null      float64
#  1   II      5 non-null      float64
#  2   III     5 non-null      float64
# dtypes: float64(3)
# memory usage: 256.0+ bytes

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#           I        II       III
# a -1.984875 -0.006250 -1.260459
# b       NaN       NaN       NaN
# c -0.261671  1.707445  0.234977
# d -0.316402 -0.878059  0.159859
# e       NaN       NaN       NaN
# f  0.052401  0.023698 -0.885729
# g       NaN       NaN       NaN
# h  0.532185  0.322891  0.139575
# i       NaN       NaN       NaN

# %%
df
# Out:
#           I        II       III
# a -1.984875 -0.006250 -1.260459
# b       NaN       NaN       NaN
# c -0.261671  1.707445  0.234977
# d -0.316402 -0.878059  0.159859
# e       NaN       NaN       NaN
# f  0.052401  0.023698 -0.885729
# g       NaN       NaN       NaN
# h  0.532185  0.322891  0.139575
# i       NaN       NaN       NaN

# %%
df.fillna(method='ffill')
# Out:
#           I        II       III
# a -1.984875 -0.006250 -1.260459
# b -1.984875 -0.006250 -1.260459
# c -0.261671  1.707445  0.234977
# d -0.316402 -0.878059  0.159859
# e -0.316402 -0.878059  0.159859
# f  0.052401  0.023698 -0.885729
# g  0.052401  0.023698 -0.885729
# h  0.532185  0.322891  0.139575
# i  0.532185  0.322891  0.139575

# %%
df.dropna()
# Out:
#           I        II       III
# a -1.984875 -0.006250 -1.260459
# c -0.261671  1.707445  0.234977
# d -0.316402 -0.878059  0.159859
# f  0.052401  0.023698 -0.885729
# h  0.532185  0.322891  0.139575

# %%
df
# Out:
#           I        II       III
# a -1.984875 -0.006250 -1.260459
# b       NaN       NaN       NaN
# c -0.261671  1.707445  0.234977
# d -0.316402 -0.878059  0.159859
# e       NaN       NaN       NaN
# f  0.052401  0.023698 -0.885729
# g       NaN       NaN       NaN
# h  0.532185  0.322891  0.139575
# i       NaN       NaN       NaN
