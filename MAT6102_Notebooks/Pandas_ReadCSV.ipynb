# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data3.txt',delimiter='\t')

# %%
df
# Out:
#     1    2  3     4
# 0   5    6  7     9
# 1  10  'a'  c  True
# 2   4    5  5     6

# %%
df = pd.read_csv('indian_cities.csv',skiprows=5,header=0)

# %%
df
# Out:
#        5      Ahmedabad  55,70,585  35,20,085      Gujarat
# 0      6        Chennai  46,81,087  43,43,645   Tamil Nadu
# 1      7        Kolkata  44,86,679  45,72,876  West Bengal
# 2      8          Surat  44,67,797  24,33,835      Gujarat
# 3      9       Vadodara  35,52,371  16,92,000      Gujarat
# 4     10           Pune  31,15,431  25,38,473  Maharashtra
# ..   ...            ...        ...        ...          ...
# 333  339      Jehanabad   1,02,456     81,503        Bihar
# 334  340     Kapurthala   1,01,654        NaN       Punjab
# 335  341     Aurangabad   1,01,520     79,393        Bihar
# 336  342        Gangtok   1,00,286     29,354       Sikkim
# 337  343  Vasco Da Gama   1,00,000        NaN          Goa
#
# [338 rows x 5 columns]

# %%
df.isnull()
# Out:
#          5  Ahmedabad  55,70,585  35,20,085  Gujarat
# 0    False      False      False      False    False
# 1    False      False      False      False    False
# 2    False      False      False      False    False
# 3    False      False      False      False    False
# 4    False      False      False      False    False
# ..     ...        ...        ...        ...      ...
# 333  False      False      False      False    False
# 334  False      False      False       True    False
# 335  False      False      False      False    False
# 336  False      False      False      False    False
# 337  False      False      False       True    False
#
# [338 rows x 5 columns]

# %%
data = pd.read_excel('WQ.xlsx')

# %%
pwd()
# Out:
# 'C:\\Users\\BSRVPrasad\\OneDrive\\PythonClass'

# %%
data.head()
# Out:
#    St. No  Depth  S.D   W.T  Salinity  Turbidity    DO    pH   TSM  NH4-N  \
# 0       1   1.00  1.0  29.5      10.0       5.21  8.37  9.05  18.0    1.5
# 1       2   2.25  0.5  30.0      10.4      16.00  6.90  8.27  23.2    9.9
# 2       3   2.50  0.5  29.6      11.8      13.70  6.79  8.27  26.8   11.2
# 3       4   1.85  NaN  29.6      10.7       3.72  5.17  8.64  22.6    2.9
# 4       5   1.50  1.5  29.3      11.7       4.22  6.46  8.70  18.0    2.3
#
#    NO2-N  NO3-N  PO4-P  SiO2-Si    TN    TP
# 0   0.45   4.20    6.3      1.5   NaN   NaN
# 1   0.39   1.04    4.5      8.0  19.1  11.6
# 2   0.30   0.79    6.0     12.0  18.6  11.6
# 3   0.21   1.07    9.3      9.0  21.1   NaN
# 4   0.41   1.09    6.6      8.0  29.1  10.8

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   St. No     36 non-null     int64
#  1   Depth      35 non-null     float64
#  2   S.D        34 non-null     float64
#  3   W.T        35 non-null     float64
#  4   Salinity   35 non-null     float64
#  5   Turbidity  35 non-null     float64
#  6   DO         35 non-null     float64
#  7   pH         35 non-null     float64
#  8   TSM        35 non-null     float64
#  9   NH4-N      35 non-null     float64
#  10  NO2-N      35 non-null     float64
#  11  NO3-N      35 non-null     float64
#  12  PO4-P      35 non-null     float64
#  13  SiO2-Si    35 non-null     float64
#  14  TN         31 non-null     float64
#  15  TP         21 non-null     float64
# dtypes: float64(15), int64(1)
# memory usage: 4.6 KB

# %%
data.loc[9]
# Out:
# St. No       10.00
# Depth         2.50
# S.D           0.50
# W.T          30.10
# Salinity     15.10
# Turbidity     9.72
# DO            6.54
# pH            8.31
# TSM          11.20
# NH4-N         4.20
# NO2-N         0.63
# NO3-N        11.59
# PO4-P         4.09
# SiO2-Si      44.90
# TN             NaN
# TP             NaN
# Name: 9, dtype: float64

# %%
data
# Out:
#     St. No  Depth    S.D   W.T  Salinity  Turbidity     DO    pH      TSM  \
# 0        1   1.00  1.000  29.5      10.0       5.21   8.37  9.05   18.000
# 1        2   2.25  0.500  30.0      10.4      16.00   6.90  8.27   23.200
# 2        3   2.50  0.500  29.6      11.8      13.70   6.79  8.27   26.800
# 3        4   1.85    NaN  29.6      10.7       3.72   5.17  8.64   22.600
# 4        5   1.50  1.500  29.3      11.7       4.22   6.46  8.70   18.000
# 5        6   2.25  1.000  30.1      12.6       7.46   6.18  8.30   22.200
# 6        7   2.35  0.750  29.8      13.9      10.50   6.98  8.28   14.500
# 7        8   0.25  0.250  31.2      13.4      11.00   7.12  8.26   15.400
# 8        9    NaN    NaN   NaN       NaN        NaN    NaN   NaN      NaN
# 9       10   2.50  0.500  30.1      15.1       9.72   6.54  8.31   11.200
# 10      11   0.75  0.750  29.0      14.8       4.48   8.36  8.53    9.440
# 11      12   1.75  0.500  30.6      15.5      19.20   6.73  8.38   19.200
# ...

# %%
data = pd.read_excel('WQ.xlsx',sheet_name='Dec 04')

# %%
data
# Out:
#     St. No  Depth   S.D   W.T  Salinity  Turbidity     DO    pH     TSM  \
# 0        1   0.50  0.50  27.5     15.36       3.50  11.28  9.18   18.00
# 1        2   2.35  0.75  25.5     15.48       8.89   9.34  8.65   24.00
# 2        3   2.65  1.00  25.1     15.87       8.34   7.97  8.44   17.95
# 3        4   2.25  2.00  25.9     16.64       1.59   7.97  8.76    9.70
# 4        5   1.75  1.75  25.8     14.97       0.81   9.59  8.67    6.00
# 5        6   2.50  0.75  25.4     14.59       5.09   8.06  8.55   16.40
# 6        7   2.75  1.50  25.1     13.82       4.98   7.25  8.46   14.25
# 7        8   0.25  0.25  25.8     13.44       0.15   9.59  8.80    9.12
# 8        9   0.25  0.25  25.6     14.08       1.77   7.25  8.64    8.50
# 9       10   2.75  1.25  25.3     13.44       4.24   7.25  8.44   15.60
# 10      11   0.50  0.50  24.4     13.31       0.47   8.86  8.47    8.50
# 11      12   1.75  0.75  25.0     12.16      10.02   7.70  8.32   24.00
# ...

# %%
df1 = pd.read_csv("data1.txt")

# %%
df2 = pd.read_csv("data2.txt")

# %%
df1
# Out:
#    1   2   3   4
# 0  5   6   7   8
# 1  9  10  11  12

# %%
df2
# Out:
#      1     2    3   4
# 0  5.0   NaN  7.0   8
# 1  NaN  10.0  NaN  12

# %%
df3 = pd.concat([df1,df2],axis=1)

# %%
df3
# Out:
#    1   2   3   4    1     2    3   4
# 0  5   6   7   8  5.0   NaN  7.0   8
# 1  9  10  11  12  NaN  10.0  NaN  12

# %%
A = np.array([[i+j+120 for j in range(6)] for i in range(5)])

# %%
A
# Out:
# array([[120, 121, 122, 123, 124, 125],
#        [121, 122, 123, 124, 125, 126],
#        [122, 123, 124, 125, 126, 127],
#        [123, 124, 125, 126, 127, 128],
#        [124, 125, 126, 127, 128, 129]])

# %%
 cfv
