# %% [markdown]
# ### Python Operators and Order of Operators

# %%
a = 7
b = 2
c = 5

# %%
print(a + b)
print(a - b)
print((a - b) * c)
# Out:
# 9
# 5
# 25

# %%
print(a - (b - c))
# Out:
# 10

# %%
a**b**c
# Out:
# 1104427674243920646305299201

# %%
b**c
# Out:
# 32

# %%
a**32
# Out:
# 1104427674243920646305299201

# %%
(a**b)**c
# Out:
# 282475249

# %%
a**(b**c)
# Out:
# 1104427674243920646305299201

# %%
a/b
# Out:
# 3.5

# %%
a//b
# Out:
# 3

# %%
2 + 4.5
# Out:
# 6.5

# %%
4.5/5.5
# Out:
# 0.8181818181818182

# %%
4.5//5.5
# Out:
# 0.0

# %%
4//5.5
# Out:
# 0.0

# %%
5.656//3
# Out:
# 1.0

# %%
a = a+2

# %%
print(a)
# Out:
# 9

# %%
a += 2
print(a)
# Out:
# 11

# %%
a *= 2
print(a)
# Out:
# 22

# %% [markdown]
# ### Python boolean/comparision operations

# %%
a > 2 or not b < 1
# Out:
# True

# %%
b
# Out:
# 2

# %%
2 + True
# Out:
# 3

# %%
2 + False
# Out:
# 2

# %%
True + True
# Out:
# 2

# %%
a = 2

# %%
b = 3

# %%
a is b
# Out:
# False

# %%
a = 2
b = a

# %%
id(a)
# Out:
# 1406950140240

# %%
id(b)
# Out:
# 1406950140240

# %%
a is b
# Out:
# True

# %%
 b = b+1

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
l = [1,2,3]

# %%
1 in l
# Out:
# True

# %%
4 in l
# Out:
# False

# %% [markdown]
# ### Timing a Jupyter cell execution

# %%
# %timeit range(100)
# Out:
# 214 ns ± 18.3 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
import numpy

# %%
# %%timeit 
x = numpy.matrix([[1,2],[2,4]])
eig = numpy.linalg.eigvals(x)
print(eig)
# Out:
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# [0. 5.]
# ...

# %% [markdown]
# ### Python Strings and Operations on Strings

# %%
S = "Helloo... This is a sample line"

# %%
S.count('e')
# Out:
# 3

# %%
S.count("This")
# Out:
# 1

# %%
S.find('e')
# Out:
# 1

# %%
S1 = '123abc'

# %%
S1.isalnum()
# Out:
# True

# %%
S1.isalpha()
# Out:
# False

# %%
S1.isdigit()
# Out:
# False

# %%
S2 = '123'

# %%
S2.isdigit()
# Out:
# True

# %%
S
# Out:
# 'Helloo... This is a sample line'

# %%
S[2:8:2]
# Out:
# 'lo.'

# %%
S[::-1]
# Out:
# 'enil elpmas a si sihT ...oolleH'

# %%
S[::-1]
# Out:
# 'enil elpmas a si sihT ...oolleH'

# %%
age = 16
txt = "Tom age is {}"

# %%
print(txt.format(age))
# Out:
# Tom age is 16

# %%
name = "Tom"
age = 36
txt = "{} age is: {}"

# %%
print(txt.format(name,age))
# Out:
# Tom age is: 36

# %%
print(txt.format(age,name))
# Out:
# 36 age is: Tom

# %%
txt1 = "{1} age is: {0}"

# %%
print(txt1.format(age,name))
# Out:
# Tom age is: 36

# %%
S
# Out:
# 'Helloo... This is a sample line'

# %%
S.replace("H","Hiii")
# Out:
# 'Hiiielloo... This is a sample line'

# %%
S.replace('This','That')
# Out:
# 'Helloo... That is a sample line'

# %%
S = 'Hello, World!'

# %%
S.split(",")
# Out:
# ['Hello', ' World!']

# %%
S.split("Wo")
# Out:
# ['Hello, ', 'rld!']

# %%
S = 'This is a sample string with sample data'

# %%
S.split('e')
# Out:
# ['This is a sampl', ' string with sampl', ' data']

# %%
S.split("sample")
# Out:
# ['This is a ', ' string with ', ' data']

# %%
S
# Out:
# 'This is a sample string with sample data'

# %%
"xyz" in S
# Out:
# False

# %%
S = "this is a sample string. this is second sentence"

# %%
S.capitalize()
# Out:
# 'This is a sample string. this is second sentence'

# %%
S.title()
# Out:
# 'This Is A Sample String. This Is Second Sentence'

# %%
S = 'This is A testing String'

# %%
S.swapcase()
# Out:
# 'tHIS IS a TESTING sTRING'

# %%
pwd = "testing"
pwd.isalnum()
# Out:
# True

# %%
pwd = "123digit@"

# %%
"$" in pwd
# Out:
# False

# %%
"1" in pwd
# Out:
# True

# %% [markdown]
# ### if...elif..else condition in Python

# %%
a = 2
b = 2
if a < b:
  print("a is less than b")
  print("This is line two")
elif a > b:
  print('a is greather than b')
else:
  print('both are equal')
# Out:
# both are equal

# %% [markdown]
# ### for loop in Python

# %%
for i in range(0,10):
    print(i, 'Hello World!')
# Out:
# 0 Hello World!
# 1 Hello World!
# 2 Hello World!
# 3 Hello World!
# 4 Hello World!
# 5 Hello World!
# 6 Hello World!
# 7 Hello World!
# 8 Hello World!
# 9 Hello World!

# %% [markdown]
# ### Iterating over a string in Python

# %%
for x in pwd:
    print(x)
# Out:
# 1
# 2
# 3
# d
# i
# g
# i
# t
# @

# %% [markdown]
# ### while loop in Python

# %%
a = 1
while a <= 10:
    print('Hello World!')
    a = a+1
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!

# %% [markdown]
# ### inline if condtion

# %%
a = 10
b = 20
print("a < b") if a < b else print("a >= b")
# Out:
# a < b

# %%
a = 20
b = 20
print("a < b") if a < b else print ("a=b") if a == b else print("a > b")
# Out:
# a=b
